# %% [markdown]
# Привет, работай в папке D:\multiagent\RL_and_PPO\bot_repetitor. Смотри, я занимаюсь репетиторством, мне нужно создать бота в телеграмм (не просто бота, а приложение), который будет представлять собой менеджер для записей учеников.
# Приложение будет в современном стиле.
# Будет подвязана база данных.
# Далее ученик открывает бота. На главном экране будет приветственное окно, Здравствуйте, имя ученика (по телеграмму) и его аватарка, краткая информация обо мне, мое фото, которое я загружу,  и ниже кнопка записаться, при нажатии кнопки будет открываться доступные дни недели и снизу свободно время. Где он может прогручивать влево/вправо смотреть даты и время. Далее нажимает на нужное время и записывается. А мне в боте приходит уведомление о записи.
# После того как ученик записался, у него меняется главное окно приложения, и написано что в такое время он записан.
# У меня будет админ панель, где я в приложении могу отметить свободное время которое у меня есть, просмотреть записи, изменит информацию обо мне и загрузить фото.
# Бота я буду размещать на моем VPS сервере, через докер. Также бот будет подвязан через git, чтобы я локально мог менять функционал бота, пушить в git, а оттуда обновляет бота на сервере. Мне пошаговую инструкцию как загрузить и менять.

# %% [markdown]
# Измени фон приложения на темно синий, с градиентами, ну и соответственно читабельный текст на фоне.

# %% [markdown]
# Отлично, добавь чтобы ученик мог отменить занятие и я мог отменить занятие через админ панель. Плюс если занятие отменяется, окно снова доступно для записи.

# %% [markdown]
# Добавь еще чтобы кто записался, за 8 часов до начала занятия, ученику приходило напоминание про занятие

# %% [markdown]
# Отлично, сделай теперь так, чтобы ученик если записался, то мог еще записываться. А то сейчас только один раз может

# %% [markdown]
# Далее, ниже фотографии, на главном экране ученика, будет окно новостей, сейчас будет Акция "Приведи друга", ниже будет написано описание, Приведи друга по ссылке на бота, скидка для тебя на следующее занятие 50 %, для нового ученика 20 %, после того, как ученик запишется на занятие. Акция и 20 % и 50 % будут посдвечены. И кнопка пригласить друга. Далее нужно продумать систему, ученик копирует ссылку, в базе помечается что скопировал и кто скопировал, и далее, новый ученик, когда открывает бота по ссылке, у него на каждом времени записи возле времени написано 20 %. И когда записывается у меня отображается что со скидкой 20 % запись. А ученик который скопировал ссылку, после того, как ученик которому он скинул ссылку запишется на занятие, у него тоже возле времени будет отображаться скидка 50 %. Такая реферальная система.

# %% [markdown]
# В онлайн записи, нет возможности прокрутить даты, то есть даты которые поместились на экран и все. А дальше пролистать нельзя. Исправь.
# При нажатии на время для записи, пусть запись не сразу, а высплывает окно, подтвердите запись, да или нет.

# %% [markdown]
# Сделай, чтобы у меня в админской понели была регулировка скидок, то есть я нажимаю кнопку, просмотр учеников, открывается список всех кто бот запустил (ученики мои) там видно у кого какая скидка если есть, могу ее убрать, изменить, у кого нет могу вручную добавить

# %% [markdown]
# Добавь Кнопку портфолио под фото, где открывается окно с моим портфолио со следующей структурой:
# Автор: более 10 научных статей в области машинного обучения и нейронных сетей. И снизу фото.
# Ниже, более 5 государственных регистраций программ ЭВМ и снизу фото
# Участник конференций и хакатонов, в том числе международных, ниже фото
# В админке могу редактировать все и добавлять фото.

# %% [markdown]
# Диплом

# %% [markdown]
# Реферальная система + окно новостей (акция)
#
# cd D:\multiagent\RL_and_PPO\bot_repetitor
# git add .
# git commit -m "Fix notification timezone formatting"
# git push
#
#
#
# cd ~/bot_repetitor
# git pull
# docker compose up -d --build

# %% [markdown]
# git clone https://github.com/3009james/bot_repetitor.git
#
# 3009james
#
# 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
